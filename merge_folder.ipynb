# %%
import os
import shutil

# %%
ls
# Out:
# MM1/     MM1_ADNI_1/     merge_folder.ipynb  test1/
# MM1.zip  MM1_ADNI_1.zip  nohup.out

# %%
desPathRoot = "/home/ubuntu/Desktop/ADNI_MRI_Image/MM1"
souPathRoot = "/home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1"

# %%
dir1 = "002_S_0729"
for root, dirs, files in os.walk(os.path.join(souPathRoot,dir1)):
    for name in files:
        print(os.path.join(root, name))
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/SURVEY
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE_REPEAT
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2009-08-13_12_47_16.0
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2007-09-05_07_54_56.0
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2006-08-02_07_02_00.0
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2006-08-02_07_13_17.0
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2008-03-05_14_35_55.0
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2008-09-29_11_52_49.0
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2008-03-05_14_48_14.0
# /home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2009-08-13_12_47_16.0/S72365
# ...

# %%
os.listdir(souPathRoot)
# Out:
# ['031_S_1066',
#  '023_S_1046',
#  '023_S_0625',
#  '027_S_0835',
#  '016_S_1117',
#  '002_S_1268',
#  '051_S_1331',
#  '051_S_1131',
#  '051_S_1072',
#  '023_S_0376',
#  '002_S_0729',
#  '033_S_0922',
#  '023_S_0331',
#  '031_S_0830',
#  '037_S_0588',
#  '016_S_1326',
#  '027_S_0307',
#  '131_S_0384',
#  '116_S_0752',
#  '037_S_0501',
#  '130_S_0505',
#  '033_S_0514',
#  '027_S_1387']

# %%
for souDir in os.listdir(souPathRoot):
    for root1, dirs1, files1 in os.walk(os.path.join(souPathRoot,souDir)):
        for name in dirs1:
            path = os.path.join(root1, name)
#             print(path)
            if len(path.split('/')) == 9:
                desPath = os.path.join(desPathRoot,souDir,path.split('/')[7])
                souPath = os.path.split(path)[0]
                if os.path.exists(desPath) and os.path.exists(souPath):
                    for dateDir in os.listdir(souPath):
#                         print(os.path.join(souPath,dateDir),desPath)
                        shutil.move(os.path.join(souPath,dateDir),desPath)
                elif os.path.exists(desPath) == False:
#                     print(os.path.split(path)[0],os.path.split(desPath)[0])
                    shutil.move(os.path.split(path)[0],os.path.split(desPath)[0])
                else:
                    pass

# %%
os.path.split("/home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE")

# %%
shutil.move('/home/ubuntu/Desktop/ADNI_MRI_Image/test2','/home/ubuntu/Desktop/ADNI_MRI_Image/test1')

# %%
os.path.exists('/home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE_REPEA')

# %%
len(desPath.split('/')) == 6

# %%
"/home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/002_S_0729/MPRAGE/2009-08-13_12_47_16.0".split('/')[7]
# Out:
# 'MPRAGE'

# %%
a = '/root/home'
os.path.join(a,'fwefw','rge')
# Out:
# '/root/home/fwefw/rge'

# %%
os.listdir("/home/ubuntu/Desktop/ADNI_MRI_Image/MM1/002_S_0729/MPRAGE")

# %%
os.path.split('/home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/031_S_1066/localizer')

# %%
os.path.join(souPath,dateDir)
# Out:
# '/home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/031_S_1066/MPRAGE/2007-12-12_11_49_31.0'

# %%
souPath
# Out:
# '/home/ubuntu/Desktop/ADNI_MRI_Image/MM1_ADNI_1/031_S_1066/MPRAGE'

# %%
shutil.move?
