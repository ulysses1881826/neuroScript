# %%
import numpy as np
import pandas as pd
import os
import json
from freesurfer_stats import CorticalParcellationStats
import re

# %%
csvPath = "/home/ubuntu/Desktop/ADNI_MRI_Image/neuroScript/csvFiles"
freesurferOutputPath = "/home/ubuntu/Desktop/ADNI_MRI_Image/MCI_freesurfer_output"

# %%
volner = pd.read_csv(os.path.join(csvPath,"Freesurfer_S1200_Extensively_Processed_fMRI_Data.csv"))

list(volner.columns)
# Out:
# ['Subject',
#  'FS_IntraCranial_Vol',
#  'FS_BrainSeg_Vol',
#  'FS_BrainSeg_Vol_No_Vent',
#  'FS_BrainSeg_Vol_No_Vent_Surf',
#  'FS_LCort_GM_Vol',
#  'FS_RCort_GM_Vol',
#  'FS_TotCort_GM_Vol',
#  'FS_SubCort_GM_Vol',
#  'FS_Total_GM_Vol',
#  'FS_SupraTentorial_Vol',
#  'FS_L_WM_Vol',
#  'FS_R_WM_Vol',
#  'FS_Tot_WM_Vol',
#  'FS_Mask_Vol',
#  'FS_BrainSegVol_eTIV_Ratio',
#  'FS_MaskVol_eTIV_Ratio',
#  'FS_LH_Defect_Holes',
#  'FS_RH_Defect_Holes',
#  'FS_Total_Defect_Holes',
#  'FS_L_LatVent_Vol',
#  'FS_L_InfLatVent_Vol',
#  'FS_L_Cerebellum_WM_Vol',
#  'FS_L_Cerebellum_Cort_Vol',
#  'FS_L_ThalamusProper_Vol',
#  'FS_L_Caudate_Vol',
#  'FS_L_Putamen_Vol',
#  'FS_L_Pallidum_Vol',
#  'FS_3rdVent_Vol',
#  'FS_4thVent_Vol',
#  'FS_BrainStem_Vol',
#  'FS_L_Hippo_Vol',
#  'FS_L_Amygdala_Vol',
#  'FS_CSF_Vol',
#  'FS_L_AccumbensArea_Vol',
#  'FS_L_VentDC_Vol',
#  'FS_L_Vessel_Vol',
#  'FS_L_ChoroidPlexus_Vol',
#  'FS_R_LatVent_Vol',
#  'FS_R_InfLatVent_Vol',
#  'FS_R_Cerebellum_WM_Vol',
#  'FS_R_Cerebellum_Cort_Vol',
#  'FS_R_ThalamusProper_Vol',
#  'FS_R_Caudate_Vol',
#  'FS_R_Putamen_Vol',
#  'FS_R_Pallidum_Vol',
#  'FS_R_Hippo_Vol',
#  'FS_R_Amygdala_Vol',
#  'FS_R_AccumbensArea_Vol',
#  'FS_R_VentDC_Vol',
#  'FS_R_Vessel_Vol',
#  'FS_R_ChoroidPlexus_Vol',
#  'FS_5thVent_Vol',
#  'FS_WM_Hypointens_Vol',
#  'FS_L_WM_Hypointens_Vol',
#  'FS_R_WM_Hypointens_Vol',
#  'FS_L_Non-WM_Hypointens_Vol',
#  'FS_R_Non-WM_Hypointens_Vol',
#  'FS_OpticChiasm_Vol',
#  'FS_CC_Posterior_Vol',
#  'FS_CC_MidPosterior_Vol',
#  'FS_CC_Central_Vol',
#  'FS_CC_MidAnterior_Vol',
#  'FS_CC_Anterior_Vol',
#  'FS_L_Bankssts_Thck',
#  'FS_L_Caudalanteriorcingulate_Thck',
#  'FS_L_Caudalmiddlefrontal_Thck',
#  'FS_L_Cuneus_Thck',
#  'FS_L_Entorhinal_Thck',
#  'FS_L_Fusiform_Thck',
#  'FS_L_Inferiorparietal_Thck',
#  'FS_L_Inferiortemporal_Thck',
#  'FS_L_Isthmuscingulate_Thck',
#  'FS_L_Lateraloccipital_Thck',
#  'FS_L_Lateralorbitofrontal_Thck',
#  'FS_L_Lingual_Thck',
#  'FS_L_Medialorbitofrontal_Thck',
#  'FS_L_Middletemporal_Thck',
#  'FS_L_Parahippocampal_Thck',
#  'FS_L_Paracentral_Thck',
#  'FS_L_Parsopercularis_Thck',
#  'FS_L_Parsorbitalis_Thck',
#  'FS_L_Parstriangularis_Thck',
#  'FS_L_Pericalcarine_Thck',
#  'FS_L_Postcentral_Thck',
#  'FS_L_Posteriorcingulate_Thck',
#  'FS_L_Precentral_Thck',
#  'FS_L_Precuneus_Thck',
#  'FS_L_Rostralanteriorcingulate_Thck',
#  'FS_L_Rostralmiddlefrontal_Thck',
#  'FS_L_Superiorfrontal_Thck',
#  'FS_L_Superiorparietal_Thck',
#  'FS_L_Superiortemporal_Thck',
#  'FS_L_Supramarginal_Thck',
#  'FS_L_Frontalpole_Thck',
#  'FS_L_Temporalpole_Thck',
#  'FS_L_Transversetemporal_Thck',
#  'FS_L_Insula_Thck',
#  'FS_R_Bankssts_Thck',
#  'FS_R_Caudalanteriorcingulate_Thck',
#  'FS_R_Caudalmiddlefrontal_Thck',
#  'FS_R_Cuneus_Thck',
#  'FS_R_Entorhinal_Thck',
#  'FS_R_Fusiform_Thck',
#  'FS_R_Inferiorparietal_Thck',
#  'FS_R_Inferiortemporal_Thck',
#  'FS_R_Isthmuscingulate_Thck',
#  'FS_R_Lateraloccipital_Thck',
#  'FS_R_Lateralorbitofrontal_Thck',
#  'FS_R_Lingual_Thck',
#  'FS_R_Medialorbitofrontal_Thck',
#  'FS_R_Middletemporal_Thck',
#  'FS_R_Parahippocampal_Thck',
#  'FS_R_Paracentral_Thck',
#  'FS_R_Parsopercularis_Thck',
#  'FS_R_Parsorbitalis_Thck',
#  'FS_R_Parstriangularis_Thck',
#  'FS_R_Pericalcarine_Thck',
#  'FS_R_Postcentral_Thck',
#  'FS_R_Posteriorcingulate_Thck',
#  'FS_R_Precentral_Thck',
#  'FS_R_Precuneus_Thck',
#  'FS_R_Rostralanteriorcingulate_Thck',
#  'FS_R_Rostralmiddlefrontal_Thck',
#  'FS_R_Superiorfrontal_Thck',
#  'FS_R_Superiorparietal_Thck',
#  'FS_R_Superiortemporal_Thck',
#  'FS_R_Supramarginal_Thck',
#  'FS_R_Frontalpole_Thck',
#  'FS_R_Temporalpole_Thck',
#  'FS_R_Transversetemporal_Thck',
#  'FS_R_Insula_Thck',
#  'FS_L_Bankssts_Area',
#  'FS_L_Caudalanteriorcingulate_Area',
#  'FS_L_Caudalmiddlefrontal_Area',
#  'FS_L_Cuneus_Area',
#  'FS_L_Entorhinal_Area',
#  'FS_L_Fusiform_Area',
#  'FS_L_Inferiorparietal_Area',
#  'FS_L_Inferiortemporal_Area',
#  'FS_L_Isthmuscingulate_Area',
#  'FS_L_Lateraloccipital_Area',
#  'FS_L_Lateralorbitofrontal_Area',
#  'FS_L_Lingual_Area',
#  'FS_L_Medialorbitofrontal_Area',
#  'FS_L_Middletemporal_Area',
#  'FS_L_Parahippocampal_Area',
#  'FS_L_Paracentral_Area',
#  'FS_L_Parsopercularis_Area',
#  'FS_L_Parsorbitalis_Area',
#  'FS_L_Parstriangularis_Area',
#  'FS_L_Pericalcarine_Area',
#  'FS_L_Postcentral_Area',
#  'FS_L_Posteriorcingulate_Area',
#  'FS_L_Precentral_Area',
#  'FS_L_Precuneus_Area',
#  'FS_L_Rostralanteriorcingulate_Area',
#  'FS_L_Rostralmiddlefrontal_Area',
#  'FS_L_Superiorfrontal_Area',
#  'FS_L_Superiorparietal_Area',
#  'FS_L_Superiortemporal_Area',
#  'FS_L_Supramarginal_Area',
#  'FS_L_Frontalpole_Area',
#  'FS_L_Temporalpole_Area',
#  'FS_L_Transversetemporal_Area',
#  'FS_L_Insula_Area',
#  'FS_R_Bankssts_Area',
#  'FS_R_Caudalanteriorcingulate_Area',
#  'FS_R_Caudalmiddlefrontal_Area',
#  'FS_R_Cuneus_Area',
#  'FS_R_Entorhinal_Area',
#  'FS_R_Fusiform_Area',
#  'FS_R_Inferiorparietal_Area',
#  'FS_R_Inferiortemporal_Area',
#  'FS_R_Isthmuscingulate_Area',
#  'FS_R_Lateraloccipital_Area',
#  'FS_R_Lateralorbitofrontal_Area',
#  'FS_R_Lingual_Area',
#  'FS_R_Medialorbitofrontal_Area',
#  'FS_R_Middletemporal_Area',
#  'FS_R_Parahippocampal_Area',
#  'FS_R_Paracentral_Area',
#  'FS_R_Parsopercularis_Area',
#  'FS_R_Parsorbitalis_Area',
#  'FS_R_Parstriangularis_Area',
#  'FS_R_Pericalcarine_Area',
#  'FS_R_Postcentral_Area',
#  'FS_R_Posteriorcingulate_Area',
#  'FS_R_Precentral_Area',
#  'FS_R_Precuneus_Area',
#  'FS_R_Rostralanteriorcingulate_Area',
#  'FS_R_Rostralmiddlefrontal_Area',
#  'FS_R_Superiorfrontal_Area',
#  'FS_R_Superiorparietal_Area',
#  'FS_R_Superiortemporal_Area',
#  'FS_R_Supramarginal_Area',
#  'FS_R_Frontalpole_Area',
#  'FS_R_Temporalpole_Area',
#  'FS_R_Transversetemporal_Area',
#  'FS_R_Insula_Area']

# %%
freeOut_columns = ['subject',##aseg.stats
                   'FS_L_ThalamusProper_Vol','FS_L_Caudate_Vol','FS_L_Putamen_Vol','FS_L_Pallidum_Vol',
                   'FS_L_Hippo_Vol','FS_L_Amygdala_Vol','FS_L_AccumbensArea_Vol','FS_R_ThalamusProper_Vol',
                   'FS_R_Caudate_Vol','FS_R_Putamen_Vol','FS_R_Pallidum_Vol','FS_R_Hippo_Vol',
                   'FS_R_Amygdala_Vol','FS_R_AccumbensArea_Vol',
                   ##aparc.stats
                   'FS_L_Bankssts_Thck',
                   'FS_L_Caudalanteriorcingulate_Thck','FS_L_Caudalmiddlefrontal_Thck',
                   'FS_L_Cuneus_Thck','FS_L_Entorhinal_Thck','FS_L_Fusiform_Thck','FS_L_Inferiorparietal_Thck',
                   'FS_L_Inferiortemporal_Thck','FS_L_Isthmuscingulate_Thck','FS_L_Lateraloccipital_Thck',
                   'FS_L_Lateralorbitofrontal_Thck','FS_L_Lingual_Thck','FS_L_Medialorbitofrontal_Thck',
                   'FS_L_Middletemporal_Thck','FS_L_Parahippocampal_Thck','FS_L_Paracentral_Thck',
                   'FS_L_Parsopercularis_Thck','FS_L_Parsorbitalis_Thck','FS_L_Parstriangularis_Thck',
                   'FS_L_Pericalcarine_Thck','FS_L_Postcentral_Thck','FS_L_Posteriorcingulate_Thck',
                   'FS_L_Precentral_Thck','FS_L_Precuneus_Thck','FS_L_Rostralanteriorcingulate_Thck',
                   'FS_L_Rostralmiddlefrontal_Thck','FS_L_Superiorfrontal_Thck','FS_L_Superiorparietal_Thck',
                   'FS_L_Superiortemporal_Thck','FS_L_Supramarginal_Thck','FS_L_Frontalpole_Thck',
                   'FS_L_Temporalpole_Thck','FS_L_Transversetemporal_Thck','FS_L_Insula_Thck',
                   'FS_R_Bankssts_Thck','FS_R_Caudalanteriorcingulate_Thck','FS_R_Caudalmiddlefrontal_Thck',
                   'FS_R_Cuneus_Thck','FS_R_Entorhinal_Thck','FS_R_Fusiform_Thck','FS_R_Inferiorparietal_Thck',
                   'FS_R_Inferiortemporal_Thck','FS_R_Isthmuscingulate_Thck','FS_R_Lateraloccipital_Thck',
                   'FS_R_Lateralorbitofrontal_Thck','FS_R_Lingual_Thck','FS_R_Medialorbitofrontal_Thck',
                   'FS_R_Middletemporal_Thck','FS_R_Parahippocampal_Thck','FS_R_Paracentral_Thck',
                   'FS_R_Parsopercularis_Thck','FS_R_Parsorbitalis_Thck','FS_R_Parstriangularis_Thck',
                   'FS_R_Pericalcarine_Thck','FS_R_Postcentral_Thck','FS_R_Posteriorcingulate_Thck',
                   'FS_R_Precentral_Thck','FS_R_Precuneus_Thck','FS_R_Rostralanteriorcingulate_Thck',
                   'FS_R_Rostralmiddlefrontal_Thck','FS_R_Superiorfrontal_Thck','FS_R_Superiorparietal_Thck',
                   'FS_R_Superiortemporal_Thck','FS_R_Supramarginal_Thck','FS_R_Frontalpole_Thck',
                   'FS_R_Temporalpole_Thck','FS_R_Transversetemporal_Thck','FS_R_Insula_Thck',
                   ##aparc.stats
                   'FS_L_bankssts_Vol',
                   'FS_L_caudalanteriorcingulate_Vol','FS_L_caudalmiddlefrontal_Vol','FS_L_cuneus_Vol',
                   'FS_L_entorhinal_Vol','FS_L_fusiform_Vol','FS_L_inferiorparietal_Vol',
                   'FS_L_inferiortemporal_Vol','FS_L_isthmuscingulate_Vol','FS_L_lateraloccipital_Vol',
                   'FS_L_lateralorbitofrontal_Vol','FS_L_lingual_Vol','FS_L_medialorbitofrontal_Vol',
                   'FS_L_middletemporal_Vol','FS_L_parahippocampal_Vol','FS_L_paracentral_Vol',
                   'FS_L_parsopercularis_Vol','FS_L_parsorbitalis_Vol','FS_L_parstriangularis_Vol',
                   'FS_L_pericalcarine_Vol','FS_L_postcentral_Vol','FS_L_posteriorcingulate_Vol',
                   'FS_L_precentral_Vol','FS_L_precuneus_Vol','FS_L_rostralanteriorcingulate_Vol',
                   'FS_L_rostralmiddlefrontal_Vol','FS_L_superiorfrontal_Vol','FS_L_superiorparietal_Vol',
                   'FS_L_superiortemporal_Vol','FS_L_supramarginal_Vol','FS_L_frontalpole_Vol',
                   'FS_L_temporalpole_Vol','FS_L_transversetemporal_Vol','FS_L_insula_Vol',
                   'FS_R_bankssts_Vol','FS_R_caudalanteriorcingulate_Vol','FS_R_caudalmiddlefrontal_Vol',
                   'FS_R_cuneus_Vol','FS_R_entorhinal_Vol','FS_R_fusiform_Vol','FS_R_inferiorparietal_Vol',
                   'FS_R_inferiortemporal_Vol','FS_R_isthmuscingulate_Vol','FS_R_lateraloccipital_Vol',
                   'FS_R_lateralorbitofrontal_Vol','FS_R_lingual_Vol','FS_R_medialorbitofrontal_Vol',
                   'FS_R_middletemporal_Vol','FS_R_parahippocampal_Vol','FS_R_paracentral_Vol',
                   'FS_R_parsopercularis_Vol','FS_R_parsorbitalis_Vol','FS_R_parstriangularis_Vol',
                   'FS_R_pericalcarine_Vol','FS_R_postcentral_Vol','FS_R_posteriorcingulate_Vol',
                   'FS_R_precentral_Vol','FS_R_precuneus_Vol','FS_R_rostralanteriorcingulate_Vol',
                   'FS_R_rostralmiddlefrontal_Vol','FS_R_superiorfrontal_Vol','FS_R_superiorparietal_Vol',
                   'FS_R_superiortemporal_Vol','FS_R_supramarginal_Vol','FS_R_frontalpole_Vol',
                   'FS_R_temporalpole_Vol','FS_R_transversetemporal_Vol','FS_R_insula_Vol',
                   'FS_L_Bankssts_Area','FS_L_Caudalanteriorcingulate_Area','FS_L_Caudalmiddlefrontal_Area',
                   'FS_L_Cuneus_Area','FS_L_Entorhinal_Area','FS_L_Fusiform_Area','FS_L_Inferiorparietal_Area',
                   'FS_L_Inferiortemporal_Area','FS_L_Isthmuscingulate_Area','FS_L_Lateraloccipital_Area',
                   'FS_L_Lateralorbitofrontal_Area','FS_L_Lingual_Area','FS_L_Medialorbitofrontal_Area',
                   'FS_L_Middletemporal_Area','FS_L_Parahippocampal_Area','FS_L_Paracentral_Area',
                   'FS_L_Parsopercularis_Area','FS_L_Parsorbitalis_Area','FS_L_Parstriangularis_Area',
                   'FS_L_Pericalcarine_Area','FS_L_Postcentral_Area','FS_L_Posteriorcingulate_Area',
                   'FS_L_Precentral_Area','FS_L_Precuneus_Area','FS_L_Rostralanteriorcingulate_Area',
                   'FS_L_Rostralmiddlefrontal_Area','FS_L_Superiorfrontal_Area','FS_L_Superiorparietal_Area',
                   'FS_L_Superiortemporal_Area','FS_L_Supramarginal_Area','FS_L_Frontalpole_Area',
                   'FS_L_Temporalpole_Area','FS_L_Transversetemporal_Area','FS_L_Insula_Area',
                   'FS_R_Bankssts_Area','FS_R_Caudalanteriorcingulate_Area','FS_R_Caudalmiddlefrontal_Area',
                   'FS_R_Cuneus_Area','FS_R_Entorhinal_Area','FS_R_Fusiform_Area','FS_R_Inferiorparietal_Area',
                   'FS_R_Inferiortemporal_Area','FS_R_Isthmuscingulate_Area','FS_R_Lateraloccipital_Area',
                   'FS_R_Lateralorbitofrontal_Area','FS_R_Lingual_Area','FS_R_Medialorbitofrontal_Area',
                   'FS_R_Middletemporal_Area','FS_R_Parahippocampal_Area','FS_R_Paracentral_Area',
                   'FS_R_Parsopercularis_Area','FS_R_Parsorbitalis_Area','FS_R_Parstriangularis_Area',
                   'FS_R_Pericalcarine_Area','FS_R_Postcentral_Area','FS_R_Posteriorcingulate_Area',
                   'FS_R_Precentral_Area','FS_R_Precuneus_Area','FS_R_Rostralanteriorcingulate_Area',
                   'FS_R_Rostralmiddlefrontal_Area','FS_R_Superiorfrontal_Area','FS_R_Superiorparietal_Area',
                   'FS_R_Superiortemporal_Area','FS_R_Supramarginal_Area','FS_R_Frontalpole_Area',
                   'FS_R_Temporalpole_Area','FS_R_Transversetemporal_Area','FS_R_Insula_Area',
                   'FS_BrainSeg_Vol_No_Vent_Surf']

# %%
freeOut = pd.DataFrame(columns=freeOut_columns)
for subject in os.listdir(freesurferOutputPath):
    tempColumnDict = {}
    for root, dirs, files in os.walk(os.path.join(freesurferOutputPath,subject)):
        for name in files:
            if name == "lh.aparc.stats":
                path = os.path.join(root,name)
                with open(path) as f:
                    lines = f.readlines()
                    for v in freeOut_columns[1:]:
                        r2f = v.split('_')[1].lower()
                        region_name = v.split('_')[2].lower()
                        vol2thck = v.split('_')[3]
                        for line in lines:
                            lineList = line.split()
                            if region_name == lineList[0] and r2f == name[0]:
                                if vol2thck == 'Vol':
                                    tempColumnDict[v] = np.float64(lineList[3])
                                if vol2thck == 'Area':
                                    tempColumnDict[v] = np.float64(lineList[2])
                                if vol2thck == 'Thck':
                                    tempColumnDict[v] = np.float64(lineList[4])
            if name == "rh.aparc.stats":
                path = os.path.join(root,name)
                with open(path) as f:
                    lines = f.readlines()
                    for v in freeOut_columns[1:]:
                        r2f = v.split('_')[1].lower()
                        region_name = v.split('_')[2].lower()
                        vol2thck = v.split('_')[3]
                        for line in lines:
                            lineList = line.split()
                            if region_name == lineList[0] and r2f == name[0]:
                                if vol2thck == 'Vol':
                                    tempColumnDict[v] = np.float64(lineList[3])
                                if vol2thck == 'Area':
                                    tempColumnDict[v] = np.float64(lineList[2])
                                if vol2thck == 'Thck':
                                    tempColumnDict[v] = np.float64(lineList[4])
            if name == "aseg.stats":
                path = os.path.join(root,name)
                with open(path) as f:
    #                 for line in f:
    #                     print(line.split())
                    lines = f.readlines()
                    for v in freeOut_columns[1:]:
                        if v.split('_')[-1] == "Vol" or v.split('_')[-1] == "Surf":
                            r2l = v.split('_')[1]
                            try:
                                region_name = re.findall('[A-Z][^A-Z]*',v.split('_')[2])[0]
                            except:
                                pass
                            vol2thck = v.split('_')[3]
                            for line in lines:
                                lineList = line.split()
                                try:
                                    if lineList[4].split('-')[1][0:5] == region_name and lineList[4][0] == r2l:
                                        tempColumnDict[v] = np.float64(lineList[3])
                                    if region_name == lineList[4].split('-')[1] and lineList[4][0] == r2l:
                                        tempColumnDict[v] = np.float64(lineList[3])
                                except:
                                    pass
                                try:
                                    if v.split('_')[-1] == re.findall('[A-Z][^A-Z]*',lineList[2])[-1][:-1]:
                                        tempColumnDict[v] = (lineList[11])
                                except:
                                    pass
    tempColumnDict["subject"] = subject
    freeOut = freeOut.append(tempColumnDict,ignore_index=True)

# %%
freeOut
# Out:
#       subject  FS_L_ThalamusProper_Vol  FS_L_Caudate_Vol  FS_L_Putamen_Vol  \
# 0  002_S_4251                   6472.4            3076.4            4532.2
# 1  002_S_2073                   6538.4            3449.6            4368.0
# 2  002_S_4219                   6178.3            3164.6            2690.8
# 3  002_S_2010                   6412.1            3214.7            4455.7
# 4  002_S_2043                   6313.1            3182.3            3501.6
# 5  002_S_4447                   6106.5            3218.1            4633.5
# 6  002_S_4229                   6638.1            3405.3            4892.7
# 7  002_S_4171                   6635.0            2789.0            3881.9
#
#    FS_L_Pallidum_Vol  FS_L_Hippo_Vol  FS_L_Amygdala_Vol  \
# 0             1735.3          3761.1             1490.5
# 1             1887.9          3912.0             1781.2
# 2             1088.3          3318.6             1262.0
# 3             1503.8          3813.9             1565.7
# 4             1630.2          3588.5             1436.6
# 5             1773.3          3243.7             1429.5
# 6             2248.0          3485.5             1898.5
# 7             1767.2          3655.8             1330.9
#
#    FS_L_AccumbensArea_Vol  FS_R_ThalamusProper_Vol  FS_R_Caudate_Vol  ...  \
# 0                   484.4                   5923.0            3038.2  ...
# 1                   478.3                   6428.7            3425.2  ...
# 2                   447.7                   5283.3            3486.1  ...
# 3                   440.0                   6295.4            3465.5  ...
# 4                   383.4                   5828.6            3470.6  ...
# 5                   427.6                   5805.8            3626.1  ...
# 6                   396.0                   6036.9            3590.6  ...
# 7                   363.5                   6130.7            3064.0  ...
#
#    FS_R_Rostralmiddlefrontal_Area  FS_R_Superiorfrontal_Area  \
# 0                          5746.0                     7018.0
# 1                          5767.0                     6594.0
# 2                          5079.0                     5980.0
# 3                          5154.0                     7355.0
# 4                          5188.0                     7027.0
# 5                          5092.0                     6002.0
# 6                          5415.0                     7313.0
# 7                          5058.0                     6584.0
#
#    FS_R_Superiorparietal_Area  FS_R_Superiortemporal_Area  \
# 0                      4792.0                      3888.0
# 1                      5058.0                      3430.0
# 2                      4949.0                      3402.0
# 3                      4497.0                      3866.0
# 4                      5004.0                      3309.0
# 5                      4707.0                      3004.0
# 6                      4839.0                      3431.0
# 7                      5319.0                      3531.0
#
#    FS_R_Supramarginal_Area  FS_R_Frontalpole_Area  FS_R_Temporalpole_Area  \
# 0                   3467.0                  330.0                   515.0
# 1                   3240.0                  282.0                   541.0
# 2                   3489.0                  313.0                   400.0
# 3                   3142.0                  281.0                   380.0
# 4                   3504.0                  265.0                   394.0
# 5                   3040.0                  321.0                   423.0
# 6                   3336.0                  346.0                   475.0
# 7                   3470.0                  309.0                   441.0
#
#    FS_R_Transversetemporal_Area  FS_R_Insula_Area  \
# 0                         415.0            2774.0
# 1                         347.0            2254.0
# 2                         302.0            2173.0
# 3                         332.0            2378.0
# 4                         331.0            2170.0
# 5                         284.0            1972.0
# 6                         285.0            2746.0
# 7                         292.0            2072.0
#
#    FS_BrainSeg_Vol_No_Vent_Surf
# 0               1054881.006724,
# 1               1086289.958278,
# 2                963154.254330,
# 3                906600.007181,
# 4               1022473.280219,
# 5                962057.489052,
# 6               1046897.509509,
# 7                992041.920969,
#
# [8 rows x 220 columns]

# %%
freeOut.to_csv(os.path.join(csvPath,"freeStatsOut.csv"))

# %%
for i in freeOut_columns:
    if i not in list(tempDict.keys()):
        print(i)

# %%
students = [ ('jack', 34, 'Sydeny' , 'Australia') ,
             ('Riti', 30, 'Delhi' , 'India' ) ,
             ('Vikas', 31, 'Mumbai' , 'India' ) ,
             ('Neelu', 32, 'Bangalore' , 'India' ) ,
             ('John', 16, 'New York' , 'US') ,
             ('Mike', 17, 'las vegas' , 'US')  ]
 
#Create a DataFrame object
dfObj = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=['a', 'b', 'c' , 'd' , 'e' , 'f'])

# %%
tempDict
# Out:
# {'subject': '002_S_4171',
#  'FS_R_Bankssts_Thck': '2.502',
#  'FS_R_Caudalanteriorcingulate_Thck': '2.385',
#  'FS_R_Caudalmiddlefrontal_Thck': '2.410',
#  'FS_R_Cuneus_Thck': '2.008',
#  'FS_R_Entorhinal_Thck': '3.018',
#  'FS_R_Fusiform_Thck': '2.970',
#  'FS_R_Inferiorparietal_Thck': '2.331',
#  'FS_R_Inferiortemporal_Thck': '2.612',
#  'FS_R_Isthmuscingulate_Thck': '2.084',
#  'FS_R_Lateraloccipital_Thck': '2.319',
#  'FS_R_Lateralorbitofrontal_Thck': '2.539',
#  'FS_R_Lingual_Thck': '2.201',
#  'FS_R_Medialorbitofrontal_Thck': '2.233',
#  'FS_R_Middletemporal_Thck': '2.689',
#  'FS_R_Parahippocampal_Thck': '3.177',
#  'FS_R_Paracentral_Thck': '2.381',
#  'FS_R_Parsopercularis_Thck': '2.326',
#  'FS_R_Parsorbitalis_Thck': '2.677',
#  'FS_R_Parstriangularis_Thck': '2.344',
#  'FS_R_Pericalcarine_Thck': '1.537',
#  'FS_R_Postcentral_Thck': '1.892',
#  'FS_R_Posteriorcingulate_Thck': '2.376',
#  'FS_R_Precentral_Thck': '2.424',
#  'FS_R_Precuneus_Thck': '2.199',
#  'FS_R_Rostralanteriorcingulate_Thck': '2.761',
#  'FS_R_Rostralmiddlefrontal_Thck': '2.253',
#  'FS_R_Superiorfrontal_Thck': '2.570',
#  'FS_R_Superiorparietal_Thck': '2.201',
#  'FS_R_Superiortemporal_Thck': '2.610',
#  'FS_R_Supramarginal_Thck': '2.401',
#  'FS_R_Frontalpole_Thck': '2.481',
#  'FS_R_Temporalpole_Thck': '3.546',
#  'FS_R_Transversetemporal_Thck': '2.557',
#  'FS_R_Insula_Thck': '2.993',
#  'FS_R_bankssts_Vol': '389.6',
#  'FS_R_caudalanteriorcingulate_Vol': '389.6',
#  'FS_R_caudalmiddlefrontal_Vol': '389.6',
#  'FS_R_cuneus_Vol': '389.6',
#  'FS_R_entorhinal_Vol': '389.6',
#  'FS_R_fusiform_Vol': '389.6',
#  'FS_R_inferiorparietal_Vol': '389.6',
#  'FS_R_inferiortemporal_Vol': '389.6',
#  'FS_R_isthmuscingulate_Vol': '389.6',
#  'FS_R_lateraloccipital_Vol': '389.6',
#  'FS_R_lateralorbitofrontal_Vol': '389.6',
#  'FS_R_lingual_Vol': '389.6',
#  'FS_R_medialorbitofrontal_Vol': '389.6',
#  'FS_R_middletemporal_Vol': '389.6',
#  'FS_R_parahippocampal_Vol': '389.6',
#  'FS_R_paracentral_Vol': '389.6',
#  'FS_R_parsopercularis_Vol': '389.6',
#  'FS_R_parsorbitalis_Vol': '389.6',
#  'FS_R_parstriangularis_Vol': '389.6',
#  'FS_R_pericalcarine_Vol': '389.6',
#  'FS_R_postcentral_Vol': '389.6',
#  'FS_R_posteriorcingulate_Vol': '389.6',
#  'FS_R_precentral_Vol': '389.6',
#  'FS_R_precuneus_Vol': '389.6',
#  'FS_R_rostralanteriorcingulate_Vol': '389.6',
#  'FS_R_rostralmiddlefrontal_Vol': '389.6',
#  'FS_R_superiorfrontal_Vol': '389.6',
#  'FS_R_superiorparietal_Vol': '389.6',
#  'FS_R_superiortemporal_Vol': '389.6',
#  'FS_R_supramarginal_Vol': '389.6',
#  'FS_R_frontalpole_Vol': '389.6',
#  'FS_R_temporalpole_Vol': '389.6',
#  'FS_R_transversetemporal_Vol': '389.6',
#  'FS_R_insula_Vol': '389.6',
#  'FS_R_Bankssts_Area': '869',
#  'FS_R_Caudalanteriorcingulate_Area': '549',
#  'FS_R_Caudalmiddlefrontal_Area': '2114',
#  'FS_R_Cuneus_Area': '1592',
#  'FS_R_Entorhinal_Area': '475',
#  'FS_R_Fusiform_Area': '2481',
#  'FS_R_Inferiorparietal_Area': '4093',
#  'FS_R_Inferiortemporal_Area': '2777',
#  'FS_R_Isthmuscingulate_Area': '1062',
#  'FS_R_Lateraloccipital_Area': '4833',
#  'FS_R_Lateralorbitofrontal_Area': '2718',
#  'FS_R_Lingual_Area': '3316',
#  'FS_R_Medialorbitofrontal_Area': '1986',
#  'FS_R_Middletemporal_Area': '3190',
#  'FS_R_Parahippocampal_Area': '518',
#  'FS_R_Paracentral_Area': '1514',
#  'FS_R_Parsopercularis_Area': '1214',
#  'FS_R_Parsorbitalis_Area': '823',
#  'FS_R_Parstriangularis_Area': '1301',
#  'FS_R_Pericalcarine_Area': '1398',
#  'FS_R_Postcentral_Area': '4072',
#  'FS_R_Posteriorcingulate_Area': '1217',
#  'FS_R_Precentral_Area': '5170',
#  'FS_R_Precuneus_Area': '4167',
#  'FS_R_Rostralanteriorcingulate_Area': '521',
#  'FS_R_Rostralmiddlefrontal_Area': '5058',
#  'FS_R_Superiorfrontal_Area': '6584',
#  'FS_R_Superiorparietal_Area': '5319',
#  'FS_R_Superiortemporal_Area': '3531',
#  'FS_R_Supramarginal_Area': '3470',
#  'FS_R_Frontalpole_Area': '309',
#  'FS_R_Temporalpole_Area': '441',
#  'FS_R_Transversetemporal_Area': '292',
#  'FS_R_Insula_Area': '2072',
#  'FS_L_ThalamusProper_Vol': '6635.0',
#  'FS_L_Caudate_Vol': '2789.0',
#  'FS_L_Putamen_Vol': '3881.9',
#  'FS_L_Pallidum_Vol': '1767.2',
#  'FS_L_Hippo_Vol': '3655.8',
#  'FS_L_Amygdala_Vol': '1330.9',
#  'FS_L_AccumbensArea_Vol': '363.5',
#  'FS_R_ThalamusProper_Vol': '6130.7',
#  'FS_R_Caudate_Vol': '3064.0',
#  'FS_R_Putamen_Vol': '4102.5',
#  'FS_R_Pallidum_Vol': '1740.7',
#  'FS_R_Hippo_Vol': '3898.0',
#  'FS_R_Amygdala_Vol': '1628.5',
#  'FS_R_AccumbensArea_Vol': '389.6',
#  'FS_L_bankssts_Vol': '1448',
#  'FS_L_caudalanteriorcingulate_Vol': '1473',
#  'FS_L_caudalmiddlefrontal_Vol': '6145',
#  'FS_L_cuneus_Vol': '3012',
#  'FS_L_entorhinal_Vol': '1589',
#  'FS_L_fusiform_Vol': '7436',
#  'FS_L_inferiorparietal_Vol': '7559',
#  'FS_L_inferiortemporal_Vol': '5938',
#  'FS_L_isthmuscingulate_Vol': '2255',
#  'FS_L_lateraloccipital_Vol': '11026',
#  'FS_L_lateralorbitofrontal_Vol': '7101',
#  'FS_L_lingual_Vol': '7104',
#  'FS_L_medialorbitofrontal_Vol': '4739',
#  'FS_L_middletemporal_Vol': '6565',
#  'FS_L_parahippocampal_Vol': '1962',
#  'FS_L_paracentral_Vol': '3380',
#  'FS_L_parsopercularis_Vol': '3659',
#  'FS_L_parsorbitalis_Vol': '2211',
#  'FS_L_parstriangularis_Vol': '2755',
#  'FS_L_pericalcarine_Vol': '1688',
#  'FS_L_postcentral_Vol': '10651',
#  'FS_L_posteriorcingulate_Vol': '3118',
#  'FS_L_precentral_Vol': '14908',
#  'FS_L_precuneus_Vol': '8628',
#  'FS_L_rostralanteriorcingulate_Vol': '2199',
#  'FS_L_rostralmiddlefrontal_Vol': '11581',
#  'FS_L_superiorfrontal_Vol': '19643',
#  'FS_L_superiorparietal_Vol': '12727',
#  'FS_L_superiortemporal_Vol': '10612',
#  'FS_L_supramarginal_Vol': '9875',
#  'FS_L_frontalpole_Vol': '887',
#  'FS_L_temporalpole_Vol': '1976',
#  'FS_L_transversetemporal_Vol': '1273',
#  'FS_L_insula_Vol': '6418',
#  'FS_BrainSeg_Vol_No_Vent_Surf': '992041.920969,',
#  'FS_L_Bankssts_Thck': '1.948',
#  'FS_L_Caudalanteriorcingulate_Thck': '2.354',
#  'FS_L_Caudalmiddlefrontal_Thck': '2.330',
#  'FS_L_Cuneus_Thck': '1.851',
#  'FS_L_Entorhinal_Thck': '2.909',
#  'FS_L_Fusiform_Thck': '2.542',
#  'FS_L_Inferiorparietal_Thck': '2.101',
#  'FS_L_Inferiortemporal_Thck': '2.291',
#  'FS_L_Isthmuscingulate_Thck': '1.868',
#  'FS_L_Lateraloccipital_Thck': '2.218',
#  'FS_L_Lateralorbitofrontal_Thck': '2.576',
#  'FS_L_Lingual_Thck': '2.076',
#  'FS_L_Medialorbitofrontal_Thck': '2.435',
#  'FS_L_Middletemporal_Thck': '2.340',
#  'FS_L_Parahippocampal_Thck': '2.672',
#  'FS_L_Paracentral_Thck': '2.429',
#  'FS_L_Parsopercularis_Thck': '2.424',
#  'FS_L_Parsorbitalis_Thck': '2.647',
#  'FS_L_Parstriangularis_Thck': '2.316',
#  'FS_L_Pericalcarine_Thck': '1.604',
#  'FS_L_Postcentral_Thck': '2.011',
#  'FS_L_Posteriorcingulate_Thck': '2.295',
#  'FS_L_Precentral_Thck': '2.491',
#  'FS_L_Precuneus_Thck': '2.089',
#  'FS_L_Rostralanteriorcingulate_Thck': '2.439',
#  'FS_L_Rostralmiddlefrontal_Thck': '2.269',
#  'FS_L_Superiorfrontal_Thck': '2.512',
#  'FS_L_Superiorparietal_Thck': '2.166',
#  'FS_L_Superiortemporal_Thck': '2.374',
#  'FS_L_Supramarginal_Thck': '2.297',
#  'FS_L_Frontalpole_Thck': '2.895',
#  'FS_L_Temporalpole_Thck': '3.138',
#  'FS_L_Transversetemporal_Thck': '2.308',
#  'FS_L_Insula_Thck': '2.897',
#  'FS_L_Bankssts_Area': '755',
#  'FS_L_Caudalanteriorcingulate_Area': '519',
#  'FS_L_Caudalmiddlefrontal_Area': '2389',
#  'FS_L_Cuneus_Area': '1551',
#  'FS_L_Entorhinal_Area': '419',
#  'FS_L_Fusiform_Area': '2566',
#  'FS_L_Inferiorparietal_Area': '3294',
#  'FS_L_Inferiortemporal_Area': '2212',
#  'FS_L_Isthmuscingulate_Area': '1050',
#  'FS_L_Lateraloccipital_Area': '4512',
#  'FS_L_Lateralorbitofrontal_Area': '2563',
#  'FS_L_Lingual_Area': '3171',
#  'FS_L_Medialorbitofrontal_Area': '1831',
#  'FS_L_Middletemporal_Area': '2183',
#  'FS_L_Parahippocampal_Area': '610',
#  'FS_L_Paracentral_Area': '1251',
#  'FS_L_Parsopercularis_Area': '1359',
#  'FS_L_Parsorbitalis_Area': '626',
#  'FS_L_Parstriangularis_Area': '1101',
#  'FS_L_Pericalcarine_Area': '1159',
#  'FS_L_Postcentral_Area': '4704',
#  'FS_L_Posteriorcingulate_Area': '1193',
#  'FS_L_Precentral_Area': '5515',
#  'FS_L_Precuneus_Area': '3848',
#  'FS_L_Rostralanteriorcingulate_Area': '781',
#  'FS_L_Rostralmiddlefrontal_Area': '4488',
#  'FS_L_Superiorfrontal_Area': '6897',
#  'FS_L_Superiorparietal_Area': '5223',
#  'FS_L_Superiortemporal_Area': '4008',
#  'FS_L_Supramarginal_Area': '3966',
#  'FS_L_Frontalpole_Area': '212',
#  'FS_L_Temporalpole_Area': '427',
#  'FS_L_Transversetemporal_Area': '474',
#  'FS_L_Insula_Area': '2258'}

# %%
testColumn = ['FS_L_ThalamusProper_Vol','FS_L_Caudate_Vol','FS_L_Lateralorbitofrontal_Thck','FS_L_Lingual_Thck']

# %%
testPath = "/home/ubuntu/Desktop/ADNI_MRI_Image/MCI_freesurfer_output/002_S_4447"
